# %%
# dialated convolutions

# %% [markdown]
# ![Screenshot 2025-07-27 190633.png](data:image/png;base64,...)

# %%
# transposed convolutions

# %% [markdown]
# ![Screenshot 2025-07-27 190748.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-07-27 190822.png](data:image/png;base64,...)

# %%
# cnn architecture

# %% [markdown]
# ![Screenshot 2025-07-27 182226.png](data:image/png;base64,...)

# %%
# convolution operations

# %% [markdown]
# ![Screenshot 2025-07-27 110019.png](data:image/png;base64,...)![Screenshot 2025-07-27 105522.png](data:image/png;base64,...)

# %%
# filters

# %% [markdown]
# ![Screenshot 2025-07-27 114817.png](data:image/png;base64,...)![Screenshot 2025-07-27 110340.png](data:image/png;base64,...)

# %%
# padding & striding

# %% [markdown]
# ![Screenshot 2025-07-27 120233.png](data:image/png;base64,...)![Screenshot 2025-07-27 125731.png](data:image/png;base64,...)
