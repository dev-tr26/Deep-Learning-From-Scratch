# %%
import pandas as pd
import numpy as np

# %% [markdown]
#  ## **perceptron trick**

# %% [markdown]
# algo : for i in range(epochs)
#         select random point(i)
#         W_n= Wo + alpha* (Y - Y_hat )*lambda_i

# %%
from sklearn.datasets import make_classification
x,y = make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0
                          ,n_classes=2,n_clusters_per_class=1,random_state=41, hypercube=False,class_sep=10)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))
plt.scatter(x[:,0],x[:,1],c=y,cmap='rainbow',s=100)

# %%
def step(z):
  return 1 if z>0 else 0

# %%
def perceptron(x,y):
  x =np.insert(x,0,1 ,axis=1)
  weights = np.ones(x.shape[1])
  alpha = 0.01                    # learning rate

  for i in range(1000):
    j = np.random.randint(0,100)
    y_hat = step(np.dot(x[j],weights))
    weights = weights + alpha*(y[j]-y_hat)*x[j]

  return weights[0],weights[1:]

# %%
intercept, coeff  = perceptron(x,y)

# %%
print(intercept)
# Out:
# 0.8899999999999999

# %%
print(coeff)
# Out:
# [1.31683431 0.243658  ]

# %%
slope = (coeff[0]/coeff[1])
b = (intercept/coeff[1])

# %%
slope
# Out:
# np.float64(5.404437083484627)

# %%
b
# Out:
# np.float64(3.652660753992462)

# %%
X = np.linspace(-3,3,100)
Y = slope * X + b

# %%
plt.figure(figsize=(10,4))
plt.plot(X,Y,color='green', linewidth=4)
plt.scatter(x[:,0],x[:,1],c=y,cmap='rainbow',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
from typing_extensions import LiteralString
def perceptron(x,y):
  m = []
  b = []

  x = np.insert(x,0,1,axis=1)
  weights = np.ones(x.shape[1])
  learning_rate = 0.01

  for i in range(200):
    j = np.random.randint(0,100)
    y_hat = step(np.dot(x[j],weights))
    weights = weights + learning_rate*(y[j]-y_hat)*x[j]

    m.append(-(weights[1]/weights[2]))
    b.append(-(weights[0]/weights[2]))

  return m,b

# %%
m,b = perceptron(x,y)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-25-b5f7b83718b1> in <cell line: 0>()
# ----> 1 m,b = perceptron(x,y)
#
# <ipython-input-23-29a797fd970c> in perceptron(x, y)
#       4   b = []
#       5
# ----> 6   x = np.insert(x,0,1,axis=1)
#       7   weights = np.ones(x.shape[1])
#       8   learning_rate = 0.01
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py in insert(arr, obj, values, axis)
#    5678         axis = ndim - 1
#    5679     else:
# -> 5680         axis = normalize_axis_index(axis, ndim)
#    5681     slobj = [slice(None)]*ndim
#    5682     N = arr.shape[axis]
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
# %matplotlib notebook
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# %%
fig,ax = plt.subplots(figsize=(10,4))

x_i = np.arange(-3,3,0.1)
y_i = x_i * slope[0] + b[0]
ax.scatter(x[:,0],x[:,1],c=y , cmap='winter',s=100)
line =ax.plot(x_i,x_i*slope[0] + b[0], 'r-',linewidth=2)
plt.ylim(-3,3)
# Out:
# <div id='b1f8e9d3-8edd-4af7-a1e9-375056789fa3'></div>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-243af541e632> in <cell line: 0>()
#       2
#       3 x_i = np.arange(-3,3,0.1)
# ----> 4 y_i = x_i * slope[0] + b[0]
#       5 ax.scatter(x[:,0],x[:,1],c=y , cmap='winter',s=100)
#       6 line =ax.plot(x_i,x_i*slope[0] + b[0], 'r-',linewidth=2)
#
# IndexError: invalid index to scalar variable.
